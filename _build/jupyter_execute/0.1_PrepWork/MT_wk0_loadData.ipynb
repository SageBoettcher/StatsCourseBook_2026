# %%
# Set-up Python libraries - you need to run this but you don't need to change it
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import seaborn as sns
sns.set_theme(style='white')
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings 
warnings.simplefilter('ignore', category=FutureWarning)

# %%
cats = pd.read_csv('/Users/sageboettcher/Library/CloudStorage/Dropbox/Sage/Documents/Teaching/Oxford/Stats25_26/DataFiles/ExampleData.csv')
display(cats)
# Out:
#               CatID Sex  deadliness  slinkiness  cuddliness
# 0      Jennyanydots   F           5           6           6
# 1          Macavity   M           8           4           1
# 2  Mr. Mistoffelees   M           3           4           8
# 3        Growltiger   M           7           2           2
